# %% [markdown]
# <a href="https://colab.research.google.com/github/f0rGoT-Ten/Data-Cleaning/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/dataset.csv")
print(df)
# Out:
#                                                 questions  \
# 0       asking about the control measure for aphid inf...
# 1       asking about the control measure of flower dro...
# 2       asking about how to avail kisan credit card lo...
# 3           asking about source of early ahu rice variety
# 4       asking that he has not got proper friut from h...
# ...                                                   ...
# 178934          farmer  asking  query about bootle gourd.
# 178935  asking thathis 8-month pregnant cow is sufferi...
# 178936  farmer asking query regarding sowing time of b...
# 178937              asking that his 2 goat are suffering.
# 178938           asking about plant protection in pumpkin
#
#                                                   answers
# 0       suggested him to spray rogor@2ml/lit.at evenin...
# 1       suggested him to apply fertilizer in recommend...
# 2       suggested to consult with officer-marketing an...
# ...

# %%
df.head()
# Out:
#                                            questions  \
# 0  asking about the control measure for aphid inf...
# 1  asking about the control measure of flower dro...
# 2  asking about how to avail kisan credit card lo...
# 3      asking about source of early ahu rice variety
# 4  asking that he has not got proper friut from h...
#
#                                              answers
# 0  suggested him to spray rogor@2ml/lit.at evenin...
# 1  suggested him to apply fertilizer in recommend...
# 2  suggested to consult with officer-marketing an...
# 3  suggested to take early ahu rice variety from ...
# 4  suggested him to aplly recommended fertilizer ...
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
df.tail()
# Out:
#                                                 questions  \
# 178934          farmer  asking  query about bootle gourd.
# 178935  asking thathis 8-month pregnant cow is sufferi...
# 178936  farmer asking query regarding sowing time of b...
# 178937              asking that his 2 goat are suffering.
# 178938           asking about plant protection in pumpkin
#
#                                                   answers
# 178934                    apply  mahafol/bipuk @ 3gm/lit.
# 178935  tr.: 1.intacef tazo 3375mg 3 no.s @ 1 vial i/m...
# 178936  sowing time of banana: march-may.\npit size: 4...
# 178937  tr.: 1. avil tab. 10 no.s @ 1 tab. orally twic...
# 178938                                                 --

# %%
print(df.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 178934    False
# 178935    False
# 178936    False
# 178937    False
# 178938    False
# Length: 178939, dtype: bool

# %% [markdown]
# This code will show how many empty cell are there in total

# %%
df.isnull().sum()
# Out:
# questions      0
# answers      123
# dtype: int64

# %%
td.isnull().sum()
# Out:
# questions    0
# answers      0
# dtype: int64

# %%
td.tail()
# Out:
#                                                 questions  \
# 178934          farmer  asking  query about bootle gourd.
# 178935  asking thathis 8-month pregnant cow is sufferi...
# 178936  farmer asking query regarding sowing time of b...
# 178937              asking that his 2 goat are suffering.
# 178938           asking about plant protection in pumpkin
#
#                                                   answers
# 178934                    apply  mahafol/bipuk @ 3gm/lit.
# 178935  tr.: 1.intacef tazo 3375mg 3 no.s @ 1 vial i/m...
# 178936  sowing time of banana: march-may.\npit size: 4...
# 178937  tr.: 1. avil tab. 10 no.s @ 1 tab. orally twic...
# 178938                                                 --

# %%
df.dropna(inplace = True)

# %% [markdown]
# This code will show the last value of answer column

# %%
print(df['answers'].values[-1:])
# Out:
# ['--']

# %% [markdown]
# This code will show the value of last row

# %%
print(df.iloc[-1])
# Out:
# questions    asking about plant protection in pumpkin
# answers                                            --
# Name: 178938, dtype: object

# %%
df.isnull().sum()
# Out:
# questions    0
# answers      0
# dtype: int64

# %%
df.head(10)
# Out:
#                                            questions  \
# 0  asking about the control measure for aphid inf...
# 1  asking about the control measure of flower dro...
# 2  asking about how to avail kisan credit card lo...
# 3      asking about source of early ahu rice variety
# 4  asking that he has not got proper friut from h...
# 5            asking about induced breeding of fishes
# 6  asking about training for preparation of bioma...
# 7  asking about treatment of low production of mi...
# 8  asking about the premature fruit dropping of c...
# 9   asking  about  preservatives  of  tomato squash.
#
#                                              answers
# 0  suggested him to spray rogor@2ml/lit.at evenin...
# 1  suggested him to apply fertilizer in recommend...
# 2  suggested to consult with officer-marketing an...
# 3  suggested to take early ahu rice variety from ...
# 4  suggested him to aplly recommended fertilizer ...
# 5    given details about induced breeding of fishes.
# ...
